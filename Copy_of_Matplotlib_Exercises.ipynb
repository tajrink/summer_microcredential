# %% [markdown]
# <a href="https://colab.research.google.com/github/tajrink/summer_microcredential/blob/main/Copy_of_Matplotlib_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Exercises
#
# MatPlotLib Review!
#
# Take your time, Matplotlib can be tricky to understand at first.
#
# These should be relatively simple plots, however they can be hard if this is your first time with matplotlib, please feel free to reference the site documentation as you go along.
#
# # Exercises
#
# ## Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# * **Create a figure object called fig using plt.figure() **
# * **Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * **Plot (x,y) on that axes and set the labels and titles to match the plot below: **

# %%
# Create Figure 
fig = plt.figure()
from matplotlib.ticker import MaxNLocator



# Add set of axes to figure
axes = fig.add_axes([0, 0, 1, 1]) # left, bottom, width, height (range 0 to 1)
axes.tick_params(left = True, right = True, bottom = True, top = True)

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
axes.set_xlim([0, 100])
axes.set_ylim([0, 200])
axes.yaxis.set_major_locator(MaxNLocator(4))

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
from matplotlib.ticker import MaxNLocator

# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.2, 0.2]) # inset axes

axes1.tick_params(left = True,right = True, bottom = True, top = True)

axes2.xaxis.set_major_locator(MaxNLocator(5))
axes2.yaxis.set_major_locator(MaxNLocator(5))
axes2.tick_params(left = True,right = True, bottom = True, top = True)

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
from matplotlib.ticker import MaxNLocator

# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.2, 0.2]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_xlim([0, 100])
axes1.set_ylim([0, 200])
axes1.yaxis.set_major_locator(MaxNLocator(4))
axes1.tick_params(left = True,right = True, bottom = True, top = True)

# Insert Figure Axes 2
axes2.plot(x, y, 'r')
axes2.set_xlabel('x')
axes2.set_ylabel('y')
axes2.set_xlim([0, 100])
axes2.set_ylim([0, 200])
axes2.xaxis.set_major_locator(MaxNLocator(5))
axes2.yaxis.set_major_locator(MaxNLocator(4))
axes2.tick_params(left = True,right = True, bottom = True, top = True)

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
# Creates blank canvas
fig = plt.figure()

# Larger Figure Axes 1
axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes1.tick_params(left = True,right = True, bottom = True, top = True)

# Insert Figure Axes 2
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.4]) # inset axes
axes2.tick_params(left = True,right = True, bottom = True, top = True)

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 1, 1]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.4]) # inset axes

# Creates blank canvas
fig = plt.figure()

axes3 = fig.add_axes([0, 0, 1, 1]) # main axes
axes4 = fig.add_axes([0.2, 0.5, 0.4, 0.4]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, z, 'b')
axes1.set_xlabel('X')
axes1.set_ylabel('Z')
axes1.set_xlim([0, 100])
axes1.set_ylim([0, 10000])
axes1.tick_params(left = True,right = True, bottom = True, top = True)

# Insert Figure Axes 2
axes2.plot(x, y, 'b')
axes2.set_xlabel('X')
axes2.set_xlim([20, 22])
axes2.set_ylabel('Y')
axes2.set_ylim([30, 50])
axes2.set_title('zoom');
axes2.tick_params(left = True,right = True, bottom = True, top = True)

# Larger Figure Axes 3
axes3.plot(x, z, 'b')
axes3.set_xlabel('X')
axes3.set_ylabel('Z')
axes3.set_xlim([0, 100])
axes3.set_ylim([0, 10000])
axes3.tick_params(left = True,right = True, bottom = True, top = True)

# Insert Figure Axes 4
axes4.plot(x, y, 'b')
axes4.set_xlabel('X')
axes4.set_xlim([20, 22])
axes4.set_ylabel('Y')
axes4.set_ylim([30, 50])
axes4.set_title('zoom');
axes4.tick_params(left = True,right = True, bottom = True, top = True)

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
plt.subplots(nrows=1, ncols=2)
axes.tick_params(left = True,right = True, bottom = True, top = True)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
from matplotlib.ticker import MaxNLocator

fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].set_xlim([0, 100])
axes[0].set_ylim([0, 200])
axes[0].plot(x, y, 'b--',lw = 3)
axes[0].x = range(0,200,50)
axes[0].yaxis.set_major_locator(MaxNLocator(4)) 

axes[1].set_xlim([0, 100])
axes[1].set_ylim([0, 10000])
axes[1].plot(x, z, 'r', lw = 3)

# %% [markdown]
# *See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.*

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,2))
axes[0].set_xlim([0, 100])
axes[0].set_ylim([0, 200])
axes[0].plot(x, y, 'b',lw = 5)          # marker size and color
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].set_xlim([0, 100])
axes[1].set_ylim([0, 10000])
axes[1].plot(x, z, 'r--', lw = 3)       # marker size and color
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# # Cheers!
